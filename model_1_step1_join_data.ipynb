# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import json
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.preprocessing import MinMaxScaler

warnings.filterwarnings('ignore')

# %%
DATA_PATH = './data/'

# %%
catalogue_feature_names = ['type', 'availability', 'duration',
                           'feature_1', 'feature_2', 'feature_3',
                           'feature_4', 'feature_5', 'attributes']

# %%
with open(os.path.join(DATA_PATH, 'catalogue.json'), 'r') as f:
    catalogue = json.load(f)
    
catalogue = {int(k): v for k, v in catalogue.items()}

# %%
catalogue[1]
# Out:
# {'type': 'movie',
#  'availability': ['purchase', 'rent'],
#  'duration': 120,
#  'feature_1': 6610431.116079764,
#  'feature_2': 0.7732243944,
#  'feature_3': 3,
#  'feature_4': 1.1120138405,
#  'feature_5': 0.6547073468,
#  'attributes': [2786, 385, 2799, 3730, 886, 7, 11700, 42, 20, 388, 1934]}

# %%
catalogue_df = pd.DataFrame(index=catalogue.keys(), columns=catalogue_feature_names).sort_index()

#Делаю из файла json DataFrame в pandas, также создаю множество с атрибутами
attributes = set()
for key, value in tqdm_notebook(catalogue.items()):
    for col_name in catalogue_feature_names:
        catalogue_df.loc[key][col_name] =  value[col_name]
        if col_name == 'attributes':
            attributes.update(value[col_name])
# Out:
# HBox(children=(IntProgress(value=0, max=10200), HTML(value='')))

# %%
catalogue_df['type'] = catalogue_df['type'].astype(str)
catalogue_df['duration'] = catalogue_df['duration'].astype(int)
catalogue_df['feature_1'] = catalogue_df['feature_1'].astype(float)
catalogue_df['feature_2'] = catalogue_df['feature_2'].astype(float)
catalogue_df['feature_3'] = catalogue_df['feature_3'].astype(int)
catalogue_df['feature_4'] = catalogue_df['feature_4'].astype(float)
catalogue_df['feature_5'] = catalogue_df['feature_5'].astype(float)

# %%
# Теперь переведу категориальные фичи в числовые признаки
type_mapper = {'series': 0, 'movie': 1, 'multipart_movie': 2}
#attributes_mapper = {key:value for key, value in zip(attributes, range(len(attributes)))}
availability_mapper = {
    (): 0,
    ('purchase',): 1,
    ('rent',): 2,
    ('subscription',): 3,
    ('purchase', 'rent',): 4,
    ('purchase', 'subscription',): 5,
    ('rent', 'subscription',): 6,
    ('purchase', 'rent', 'subscription',): 7,
}

catalogue_df['type'] = catalogue_df['type'].map(type_mapper)

catalogue_df['availability'] = catalogue_df['availability'].apply(lambda x: availability_mapper[tuple(x)])

# %%
with open(os.path.join(DATA_PATH, 'test_users.json'), 'r') as f:
    test_users = json.load(f)['users']

# %%
transactions = pd.read_csv(
    os.path.join(DATA_PATH, 'transactions.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'consumption_mode': 'category',
        'ts': np.float64,
        'watched_time': np.uint64,
        'device_type': np.uint8,
        'device_manufacturer': np.uint8
    }
)

# %%
transactions.shape
# Out:
# (9643012, 7)

# %%
transactions.columns
# Out:
# Index(['element_uid', 'user_uid', 'consumption_mode', 'ts', 'watched_time',
#        'device_type', 'device_manufacturer'],
#       dtype='object')

# %%
transactions.head(2)
# Out:
#    element_uid  user_uid consumption_mode            ts  watched_time  \
# 0         3336      5177                S  4.430518e+07          4282
# 1          481    593316                S  4.430518e+07          2989
#
#    device_type  device_manufacturer
# 0            0                   50
# 1            0                   11

# %%
transactions = transactions.join(catalogue_df, on='element_uid')

# %%
transactions.shape
# Out:
# (9643012, 16)

# %%
transactions.head(2)
# Out:
#    element_uid  user_uid consumption_mode            ts  watched_time  \
# 0         3336      5177                S  4.430518e+07          4282
# 1          481    593316                S  4.430518e+07          2989
#
#    device_type  device_manufacturer  type  availability  duration  \
# 0            0                   50     1             7        90
# 1            0                   11     1             5        50
#
#       feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  4.166108e+07   0.739609         45   1.141929   0.654707
# 1  4.293419e+07   0.750161         11   1.119409   0.592716
#
#                                           attributes
# 0  [19924, 28181, 6732, 23032, 270, 24805, 43, 14...
# 1  [30070, 30071, 30072, 30073, 51, 52, 30074, 42...

# %%
transactions.columns
# Out:
# Index(['element_uid', 'user_uid', 'consumption_mode', 'ts', 'watched_time',
#        'device_type', 'device_manufacturer', 'type', 'availability',
#        'duration', 'feature_1', 'feature_2', 'feature_3', 'feature_4',
#        'feature_5', 'attributes'],
#       dtype='object')

# %%
transactions = transactions[['ts', 'user_uid', 'element_uid',
                         'availability', 'watched_time', 'device_type', 'device_manufacturer', 'duration'
                        ]]


transactions.columns = ['session_start_datetime', 'user_id',
                     'video_id', 'vod_type', 'session_duration', 'device_type', 'device_os', 
                      'video_duration']
transactions['watching_percentage'] = transactions['session_duration'] / (transactions['video_duration'] * 60)

# %%
transactions.head()
# Out:
#    session_start_datetime  user_id  video_id  vod_type  session_duration  \
# 0            4.430518e+07     5177      3336         7              4282
# 1            4.430518e+07   593316       481         5              2989
# 2            4.430518e+07   262355      4128         7               833
# 3            4.430518e+07    74296      6272         7              2530
# 4            4.430518e+07   340623      5543         4              6282
#
#    device_type  device_os  video_duration  watching_percentage
# 0            0         50              90             0.792963
# 1            0         11              50             0.996333
# 2            0         50             100             0.138833
# 3            0         99             100             0.421667
# 4            0         50              70             1.495714

# %%
#transactions.to_pickle('./data/df_neural.pkl')

# %%
transactions[transactions.type == 0]
# Out:
#          element_uid  user_uid consumption_mode            ts  watched_time  \
# 7               5651    490059                S  4.430518e+07          9390
# 15              5951    408050                S  4.430517e+07         20886
# 16              2429    499047                S  4.430517e+07        368576
# 24               817    493902                S  4.430517e+07          4911
# 29              2771    133315                S  4.430517e+07         10557
# 31             10108    483549                S  4.430517e+07          6478
# 33              5845    401587                S  4.430517e+07         39037
# 35              3417    412761                S  4.430517e+07          5929
# 77              4650    265411                S  4.430515e+07          1265
# 88              5741    255313                S  4.430515e+07          8900
# 125             1695    178330                S  4.430514e+07         34695
# 135             8771     12265                S  4.430514e+07         20452
# 136             8420    401587                S  4.430514e+07            64
# 137             8958    506074                S  4.430514e+07          1786
# 139             1253    430210                S  4.430514e+07         56388
# 156             2912    542344                S  4.430513e+07           110
# 165             5500    529630                S  4.430513e+07         35284
# 174             8420    514143                S  4.430513e+07           307
# 209             8958    168577                S  4.430512e+07         40561
# 212             6980    385385                S  4.430512e+07          2734
# 217             7537    512523                S  4.430512e+07        118800
# 227             7708     41023                S  4.430511e+07         92271
# 235             8420     70452                S  4.430511e+07          9464
# 237              738    335427                S  4.430511e+07         18851
# 239             8958    475926                S  4.430511e+07            96
# 250             1014    537181                S  4.430511e+07         85863
# 254             1565    398085                S  4.430511e+07         60152
# 256             6762     41339                S  4.430511e+07           166
# 257             2910    288489                S  4.430511e+07          1336
# 258             7106    520568                P  4.430511e+07        150476
# ...              ...       ...              ...           ...           ...
# 9642793         5443    296735                S  4.173067e+07         37223
# 9642796         2429     50831                S  4.173067e+07            17
# 9642800         9876    505448                S  4.173067e+07             2
# 9642811         8771    250650                S  4.173067e+07          3060
# 9642813         3637     93749                S  4.173067e+07            42
# 9642818          486    333330                S  4.173067e+07          2401
# 9642826         9615    487975                S  4.173067e+07           379
# 9642827         1427    440504                S  4.173067e+07          3011
# 9642865         3972      4466                S  4.173066e+07          9542
# 9642885         6401    325553                S  4.173066e+07          4955
# 9642902         1918    590715                S  4.173066e+07         29195
# 9642914         5845    314932                S  4.173065e+07            65
# 9642915         4026     62932                S  4.173065e+07        223216
# 9642916         9363    521553                S  4.173065e+07         23826
# 9642931         8904    165079                P  4.173065e+07         37369
# 9642946          835     93296                S  4.173065e+07         27038
# 9642950         4413    298186                S  4.173065e+07          6084
# 9642951         3812    324351                S  4.173065e+07           661
# 9642952         2429     87104                S  4.173065e+07          4028
# 9642954          835    207628                S  4.173064e+07            12
# 9642955         3837    388590                S  4.173064e+07         10456
# 9642961         7220    154104                S  4.173064e+07           867
# 9642962         5845    539557                S  4.173064e+07          5987
# 9642967         5845    202920                S  4.173064e+07             0
# 9642969          168    306823                S  4.173064e+07          7360
# 9642986         8771    349659                S  4.173064e+07            71
# 9642994         8664    105882                S  4.173064e+07        437219
# 9642997         4026    496315                S  4.173063e+07        237535
# 9642998         4520    213265                S  4.173063e+07          9968
# 9643001         5443    260354                S  4.173063e+07         72923
#
#          device_type  device_manufacturer  type  availability  duration  \
# 7                  0                   50     0             0        20
# 15                 0                   11     0             5        40
# 16                 0                   99     0             5        40
# 24                 0                   99     0             0        40
# 29                 0                   50     0             5        40
# 31                 0                   50     0             3        20
# 33                 3                   99     0             5        60
# 35                 0                   50     0             5        50
# 77                 0                   50     0             0        20
# 88                 0                   50     0             3        40
# 125                0                   11     0             3        20
# 135                0                   50     0             0        50
# 136                3                   99     0             1        40
# 137                0                   50     0             0        50
# 139                0                   99     0             5        40
# 156                0                   11     0             5         0
# 165                0                   50     0             3        60
# 174                0                   50     0             1        40
# 209                0                   11     0             0        50
# 212                0                   50     0             5        40
# 217                0                   50     0             5        40
# 227                0                   50     0             5        40
# 235                3                   99     0             1        40
# 237                0                   50     0             3        40
# 239                0                   50     0             0        50
# 250                0                   50     0             0        20
# 254                0                   99     0             5        40
# 256                0                   50     0             5        50
# 257                0                   11     0             3        50
# 258                0                   50     0             5        40
# ...              ...                  ...   ...           ...       ...
# 9642793            3                   99     0             5        30
# 9642796            0                   50     0             5        40
# 9642800            0                   99     0             5        40
# 9642811            0                   11     0             0        50
# 9642813            1                   90     0             3        50
# 9642818            0                   67     0             5        60
# 9642826            0                   90     0             3        20
# 9642827            0                   50     0             3        30
# 9642865            0                   50     0             3        60
# 239      [3243, 1240, 2343, 3162, 7, 34407, 5360, 999, ...
# 250      [34567, 34568, 34569, 14860, 270, 34570, 34571...
# 254      [12117, 33871, 33872, 12007, 1742, 7, 2083, 42...
# 256      [2321, 1873, 1178, 5902, 27420, 7, 33864, 6419...
# 257      [5837, 7806, 9792, 4209, 7, 15246, 777, 33591,...
# 258      [1961, 9939, 5195, 33663, 8861, 192, 437, 3366...
# ...                                                    ...
# 9642793  [18106, 13938, 34192, 34193, 34194, 7, 24140, ...
# 9642796  [33886, 33880, 33887, 19602, 6089, 7, 33570, 3...
# 9642800  [864, 25546, 34199, 34200, 34201, 4450, 16202,...
# 9642811  [34312, 9541, 325, 17248, 270, 34313, 42, 43, 25]
# 9642813  [34856, 34857, 34858, 12576, 7, 2391, 42, 15, ...
# 9642818  [13393, 35479, 3992, 154, 52, 35480, 31, 32, 4...
# 9642826  [20304, 23979, 1513, 9339, 15756, 7, 23434, 27...
# 9642827  [9007, 10270, 35088, 8496, 7, 27720, 35089, 35...
# 9642865  [33638, 33639, 33640, 2296, 3366, 7, 5586, 567...
# 9642885  [4199, 33811, 33812, 15323, 9416, 7, 11160, 33...
# 9642902  [28037, 6108, 432, 34455, 34456, 7, 34457, 344...
# 9642914  [548, 287, 1408, 2401, 7, 25852, 33650, 33651,...
# 9642915  [3657, 1706, 1286, 33652, 2518, 7, 33480, 3349...
# 9642916  [3337, 10264, 14503, 3778, 34597, 11757, 270, ...
# 9642931  [34507, 28037, 5723, 747, 7, 33590, 1117, 3365...
# 9642946  [801, 9398, 6904, 35015, 52, 34426, 35016, 42,...
# 9642950  [48, 318, 4624, 33817, 6799, 7, 34354, 34355, ...
# 9642951  [1604, 11812, 5185, 26306, 7195, 7, 25286, 263...
# 9642952  [33886, 33880, 33887, 19602, 6089, 7, 33570, 3...
# 9642954  [801, 9398, 6904, 35015, 52, 34426, 35016, 42,...
# 9642955  [3138, 1626, 2540, 33718, 7, 52, 63, 33719, 33...
# 9642961  [34688, 34689, 34690, 34691, 7, 3472, 1134, 15...
# 9642962  [548, 287, 1408, 2401, 7, 25852, 33650, 33651,...
# 9642967  [548, 287, 1408, 2401, 7, 25852, 33650, 33651,...
# 9642969  [3337, 23259, 27966, 33747, 33748, 270, 3780, ...
# 9642986  [34312, 9541, 325, 17248, 270, 34313, 42, 43, 25]
# 9642994  [11814, 22971, 1933, 11911, 35189, 35190, 3519...
# 9642997  [3657, 1706, 1286, 33652, 2518, 7, 33480, 3349...
# 9642998  [2264, 10519, 31909, 10444, 7, 4850, 33384, 23...
# 9643001  [18106, 13938, 34192, 34193, 34194, 7, 24140, ...
#
# [1076152 rows x 16 columns]

# %%
target = ((transactions['consumption_mode'] == 'R') | \
          (transactions['consumption_mode'] == 'P') | \
          (((transactions['type'] == 1) | (transactions['type'] == 2)) & \
            (transactions['watched_time'] / 40 >= transactions['duration'])) | \
          ((transactions['type'] == 0) & (transactions['watched_time'] / 40 >= 300))).astype(np.int8)

# %%
target.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3cd0025a8ea6> in <module>
# ----> 1 target.sum()
#
# NameError: name 'target' is not defined

# %%
transactions['target'] = target

# %%
transactions.head().T
# Out:
#                                                                      0  \
# element_uid                                                       3336
# user_uid                                                          5177
# consumption_mode                                                     S
# ts                                                         4.43052e+07
# watched_time                                                      4282
# device_type                                                          0
# device_manufacturer                                                 50
# type                                                                 1
# availability                                                         7
# duration                                                            90
# feature_1                                                  4.16611e+07
# feature_2                                                     0.739609
# feature_3                                                           45
# feature_4                                                      1.14193
# feature_5                                                     0.654707
# attributes           [19924, 28181, 6732, 23032, 270, 24805, 43, 14...
# target                                                               1
#
#                                                                      1  \
# element_uid                                                        481
# user_uid                                                        593316
# consumption_mode                                                     S
# ts                                                         4.43052e+07
# watched_time                                                      2989
# device_type                                                          0
# device_manufacturer                                                 11
# type                                                                 1
# availability                                                         5
# duration                                                            50
# feature_1                                                  4.29342e+07
# feature_2                                                     0.750161
# feature_3                                                           11
# feature_4                                                      1.11941
# feature_5                                                     0.592716
# attributes           [30070, 30071, 30072, 30073, 51, 52, 30074, 42...
# target                                                               1
#
#                                                                      2  \
# element_uid                                                       4128
# user_uid                                                        262355
# consumption_mode                                                     S
# ts                                                         4.43052e+07
# watched_time                                                       833
# device_type                                                          0
# device_manufacturer                                                 50
# type                                                                 1
# availability                                                         7
# duration                                                           100
# feature_1                                                  2.77773e+07
# feature_2                                                     0.750161
# feature_3                                                           12
# feature_4                                                      1.13008
# feature_5                                                     0.654707
# attributes           [6165, 8130, 24969, 24970, 24971, 367, 571, 27...
# target                                                               0
#
#                                                                      3  \
# element_uid                                                       6272
# user_uid                                                         74296
# consumption_mode                                                     S
# ts                                                         4.43052e+07
# watched_time                                                      2530
# device_type                                                          0
# device_manufacturer                                                 99
# type                                                                 1
# availability                                                         7
# duration                                                           100
# feature_1                                                  4.04156e+07
# feature_2                                                     0.675218
# feature_3                                                           34
# feature_4                                                      1.14027
# feature_5                                                      0.68041
# attributes           [143, 4349, 1950, 5680, 714, 7, 9036, 9037, 43...
# target                                                               0
#
#                                                                      4
# element_uid                                                       5543
# user_uid                                                        340623
# consumption_mode                                                     P
# ts                                                         4.43052e+07
# watched_time                                                      6282
# device_type                                                          0
# device_manufacturer                                                 50
# type                                                                 1
# availability                                                         4
# duration                                                            70
# feature_1                                                  9.21296e+06
# feature_2                                                     0.783234
# feature_3                                                           14
# feature_4                                                      1.11388
# feature_5                                                            0
# attributes           [10235, 1462, 4719, 9368, 1613, 7, 5402, 4300,...
# target                                                               1

# %%
bookmarks = pd.read_csv(
    os.path.join(DATA_PATH, 'bookmarks.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'ts': np.float64
    }
)

# %%
bookmarks.head(3)
# Out:
#    user_uid  element_uid            ts
# 0    301135         7185  4.430516e+07
# 1    301135         4083  4.430516e+07
# 2    301135        10158  4.430516e+07

# %%
bookmarks = bookmarks.set_index(['user_uid', 'element_uid'], verify_integrity=True)

# %%
bookmarks.tail()
# Out:
#                                 ts
# user_uid element_uid
# 524752   2557         4.173079e+07
#          8919         4.173077e+07
# 5174     3637         4.173076e+07
# 161137   9700         4.173076e+07
# 26252    8460         4.173068e+07

# %%
transactions = transactions.join(bookmarks, on=['user_uid', 'element_uid'], rsuffix='_bookmarks', how='outer')

# %%
transactions.isna().sum()
# Out:
# element_uid                  0
# user_uid                     0
# consumption_mode        683494
# ts                      683494
# watched_time            683494
# device_type             683494
# device_manufacturer     683494
# type                    683494
# availability            683494
# duration                683494
# feature_1               683494
# feature_2               683494
# feature_3               683494
# feature_4               683494
# feature_5               683494
# attributes              683494
# target                  683494
# ts_bookmarks           9378290
# dtype: int64

# %%
transactions.shape
# Out:
# (10326506, 18)

# %%
transactions['is_bookmarks'] = transactions.ts_bookmarks.notna()

# %%
transactions['is_ts_more_ts_bookmarks'] = (transactions['ts'] > transactions['ts_bookmarks']).astype(np.int8)
transactions['is_ts_more_ts_bookmarks'].loc[transactions.ts_bookmarks.isna()] = 2

# %%
transactions_cat_features = ['device_type', 'device_manufacturer', 
                             'is_ts_more_ts_bookmarks', 'consumption_mode', 
                             'is_bookmarks']

# %%
transactions.head().T
# Out:
#                                                                          0  \
# element_uid                                                           3336
# user_uid                                                              5177
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                          4282
# device_type                                                              0
# device_manufacturer                                                     50
# type                                                                     1
# availability                                                             7
# duration                                                                90
# feature_1                                                      4.16611e+07
# feature_2                                                         0.739609
# feature_3                                                               45
# feature_4                                                          1.14193
# feature_5                                                         0.654707
# attributes               [19924, 28181, 6732, 23032, 270, 24805, 43, 14...
# target                                                                   1
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
#
#                                                                          1  \
# element_uid                                                            481
# user_uid                                                            593316
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                          2989
# device_type                                                              0
# device_manufacturer                                                     11
# type                                                                     1
# availability                                                             5
# duration                                                                50
# feature_1                                                      4.29342e+07
# feature_2                                                         0.750161
# feature_3                                                               11
# feature_4                                                          1.11941
# feature_5                                                         0.592716
# attributes               [30070, 30071, 30072, 30073, 51, 52, 30074, 42...
# target                                                                   1
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
#
#                                                                          2  \
# element_uid                                                           4128
# user_uid                                                            262355
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                           833
# device_type                                                              0
# device_manufacturer                                                     50
# type                                                                     1
# availability                                                             7
# duration                                                               100
# feature_1                                                      2.77773e+07
# feature_2                                                         0.750161
# feature_3                                                               12
# feature_4                                                          1.13008
# feature_5                                                         0.654707
# attributes               [6165, 8130, 24969, 24970, 24971, 367, 571, 27...
# target                                                                   0
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
#
#                                                                          3  \
# element_uid                                                           6272
# user_uid                                                             74296
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                          2530
# device_type                                                              0
# device_manufacturer                                                     99
# type                                                                     1
# availability                                                             7
# duration                                                               100
# feature_1                                                      4.04156e+07
# feature_2                                                         0.675218
# feature_3                                                               34
# feature_4                                                          1.14027
# feature_5                                                          0.68041
# attributes               [143, 4349, 1950, 5680, 714, 7, 9036, 9037, 43...
# target                                                                   0
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
#
#                                                                          4
# element_uid                                                           5543
# user_uid                                                            340623
# consumption_mode                                                         P
# ts                                                             4.43052e+07
# watched_time                                                          6282
# device_type                                                              0
# device_manufacturer                                                     50
# type                                                                     1
# availability                                                             4
# duration                                                                70
# feature_1                                                      9.21296e+06
# feature_2                                                         0.783234
# feature_3                                                               14
# feature_4                                                          1.11388
# feature_5                                                                0
# attributes               [10235, 1462, 4719, 9368, 1613, 7, 5402, 4300,...
# target                                                                   1
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2

# %%
ratings = pd.read_csv(
    os.path.join(DATA_PATH, 'ratings.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'ts': np.float64,
        'rating': np.uint8
    }
)

# %%
ratings.head(5)
# Out:
#    user_uid  element_uid  rating            ts
# 0    571252         1364      10  4.430517e+07
# 1     63140         3037      10  4.430514e+07
# 2    443817         4363       8  4.430514e+07
# 3    359870         1364      10  4.430506e+07
# 4    359870         3578       9  4.430506e+07

# %%
ratings.set_index(['user_uid', 'element_uid'], verify_integrity=True, inplace=True)

# %%
ratings.head()
# Out:
#                       rating            ts
# user_uid element_uid
# 571252   1364             10  4.430517e+07
# 63140    3037             10  4.430514e+07
# 443817   4363              8  4.430514e+07
# 359870   1364             10  4.430506e+07
#          3578              9  4.430506e+07

# %%
transactions = transactions.join(ratings, on=['user_uid', 'element_uid'], rsuffix='_raitings', how='outer')

# %%
transactions.shape
# Out:
# (10403324, 22)

# %%
transactions['is_ts_more_ts_raitings'] = (transactions['ts'] > transactions['ts_raitings']).astype(np.int8)
transactions['is_ts_more_ts_raitings'].loc[transactions.ts_raitings.isna()] = 2

# %%
transactions.head(3).T
# Out:
#                                                                          0  \
# element_uid                                                           3336
# user_uid                                                              5177
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                          4282
# device_type                                                              0
# device_manufacturer                                                     50
# type                                                                     1
# availability                                                             7
# duration                                                                90
# feature_1                                                      4.16611e+07
# feature_2                                                         0.739609
# feature_3                                                               45
# feature_4                                                          1.14193
# feature_5                                                         0.654707
# attributes               [19924, 28181, 6732, 23032, 270, 24805, 43, 14...
# target                                                                   1
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
# rating                                                                   9
# ts_raitings                                                    4.43042e+07
# is_ts_more_ts_raitings                                                   1
#
#                                                                          1  \
# element_uid                                                            481
# user_uid                                                            593316
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                          2989
# device_type                                                              0
# device_manufacturer                                                     11
# type                                                                     1
# availability                                                             5
# duration                                                                50
# feature_1                                                      4.29342e+07
# feature_2                                                         0.750161
# feature_3                                                               11
# feature_4                                                          1.11941
# feature_5                                                         0.592716
# attributes               [30070, 30071, 30072, 30073, 51, 52, 30074, 42...
# target                                                                   1
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
# rating                                                                 NaN
# ts_raitings                                                            NaN
# is_ts_more_ts_raitings                                                   2
#
#                                                                          2
# element_uid                                                           4128
# user_uid                                                            262355
# consumption_mode                                                         S
# ts                                                             4.43052e+07
# watched_time                                                           833
# device_type                                                              0
# device_manufacturer                                                     50
# type                                                                     1
# availability                                                             7
# duration                                                               100
# feature_1                                                      2.77773e+07
# feature_2                                                         0.750161
# feature_3                                                               12
# feature_4                                                          1.13008
# feature_5                                                         0.654707
# attributes               [6165, 8130, 24969, 24970, 24971, 367, 571, 27...
# target                                                                   0
# ts_bookmarks                                                           NaN
# is_bookmarks                                                         False
# is_ts_more_ts_bookmarks                                                  2
# rating                                                                 NaN
# ts_raitings                                                            NaN
# is_ts_more_ts_raitings                                                   2

# %%
# !mkdir mydata

# %%
transactions.to_pickle('./data/joins.pkl')
